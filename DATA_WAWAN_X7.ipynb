# %% [markdown]
# <a href="https://colab.research.google.com/github/hermawant0123/HRMT/blob/main/DATA_WAWAN_X7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Data penjualan
bulan = ['Januari', 'Februari', 'Maret', 'April', 'Mei']
penjualan = [100000, 150000, 120000, 180000, 200000]

# Membuat grafik garis
plt.plot(bulan, penjualan)

# Menambahkan judul dan label
plt.title('Grafik Penjualan Bulanan')
plt.xlabel('Bulan')
plt.ylabel('Penjualan')

# Menampilkan grafik
plt.show()

# %%
print("selamat datang di kelas X-7")
# Out:
# selamat datang di kelas X-7

# %%
import matplotlib.pyplot as plt

# Data penjualan
bulan = ['Januari', 'Februari', 'Maret', 'April', 'Mei']
penjualan = [100000, 150000, 120000, 180000, 200000]

# Membuat grafik garis
plt.plot(bulan, penjualan)
